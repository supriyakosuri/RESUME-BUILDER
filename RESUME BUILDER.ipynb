# %%
# Text Variables
#Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
Name = 'kosuri sai supriya'
Title = 'Data Science'
Contact = 'kondavaram near pithapuram'
profile_description=" i would like to work in the MNC company with the development of my skulls"
ProjectsHeader = 'PROJECTS '
ProjectOneTitle = 'Increasing Kaggle Revenue'
ProjectOneDesc = '- Published by Towards Data Science\n- Analyzed user survey to recommend most profitable future revenue source\n- Cleaned/visualized data using pandas/matplotlib libraries in Python'
ProjectTwoTitle = 'NYC School Data Cleaning & Analysis'
ProjectTwoDesc = '- Cleaned and combined several tables using pandas library in Python\n- Used PDE and visualization to determine correlations for future study'
ProjectThreeTitle = 'Pandas Cleaning and Visualization'
ProjectThreeDesc = '- Cleaned data for analysis using pandas library in Python\n- Used pandas and matplotlib to explore which cars hold the most value over time'
Portfolio = 'Portfolio: rebrand.ly/ekirkland'
#WorkHeader = 'EXPERIENCE'
#WorkOneTitle = 'Example Company / Example Position'
#WorkOneTime = '8/2013-Present'
#WorkOneDesc = '- Raised $350k in startup funds, recruited/organized launch team\n- Coordinated branding and communication strategy for organization\n- Led team of 80 volunteer and staff leaders'
#WorkTwoTitle = 'Second Company / Second Position'
#WorkTwoTime = '2/2007-8/2013'
#WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'
#WorkThreeTitle = 'Third Company / Third Position'
#WorkThreeTime = '6/2004-2/2007'
#WorkThreeDesc = '- Planned/Coordianted Toronto arena event and South Africa speaking tour\n- Oversaw research for published products'
EduHeader = 'EDUCATION'
EduOneTitle = 'Example University, Bachelor of Business Administration'
EduOneTime = '2000-2004'
#degree
EduOneDesc = '- GPA : 10'
#inter
EduOneDesc_2 = '- GPA: 9'

EduTwoTitle = 'Example University, Master of Arts'
EduTwoTime = '2013-2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

#
certificateHeader ='CERTIFICATES'
certificate_1="-participated in elocution conducted at the JNTU district level"
certificate_2="-completed dhakshin prachar sabha examination "
certificate_3="-won gold medal in NMO"

 ##### cerifications
    
certificationsHeader="CERTIFICATIONS"
certification_1=" participated in SQL compitation"
certification_2=" hacker rank details"
    

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))
# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
#plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(profile_description,(.0,.890))
plt.annotate(profile_description,(.0,.870))
plt.annotate(profile_description,(.0,.850))
################## education ###########
plt.annotate(EduHeader, (.02,.800), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle,(.02,.780), weight='bold', fontsize=10)
plt.annotate(EduOneTime,(.03,.760), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.02,.7400), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.7200), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.03,.700), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc_2, (.03,.6800), weight='regular', fontsize=9, alpha=.6)
##################### projects ###############3
plt.annotate(ProjectsHeader, (.02,.6500), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.6200), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.03,.5600), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.5400), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.5000), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.4800), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.4400), weight='regular', fontsize=9)

################ certificates ###########
plt.annotate(certificateHeader, (.02,.4000), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(certificate_1,(.1,.3800), weight='regular', fontsize=10)
plt.annotate(certificate_1,(.1,.3600), weight='regular', fontsize=10)
plt.annotate(certificate_1,(.1,.3400), weight='regular', fontsize=10)

 ###################### certifications ##############
#certificationsHeader="CertificationsHeader"
certification_1=" participated in SQL compitation"
    
plt.annotate(certificationsHeader, (.02,.3000), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(certification_1,(.1,.2800), weight='regular', fontsize=10)
plt.annotate(certification_2,(.1,.2500), weight='regular', fontsize=10)
#plt.annotate(certificate_1,(.1,.3400), weight='regular', fontsize=10)















#(.02,.60), weight='bold', fontsize=10, color='#58C1B2')
#plt.annotate(EduOneTitle,(.03,.570), weight='bold', fontsize=10)
#plt.annotate(EduOneTime,(.03,.550), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(EduOneDesc, (.02,.530), weight='regular', fontsize=9)
#plt.annotate(EduTwoTitle, (.03,.500), weight='bold', fontsize=10)
#plt.annotate(EduTwoTime, (.03,.480)


#plt.annotate(Portfolio, (.02,.6), weight='bold', fontsize=10)
#plt.annotate(EduHeader, (.02,.60), weight='bold', fontsize=10, color='#58C1B2')
#plt.annotate(EduOneTitle,(.03,.570), weight='bold', fontsize=10)
#plt.annotate(EduOneTime,(.03,.550), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(EduOneDesc, (.02,.530), weight='regular', fontsize=9)
#plt.annotate(EduTwoTitle, (.03,.500), weight='bold', fontsize=10)
#plt.annotate(EduTwoTime, (.03,.480), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkHeader, (.02,.50), weight='bold', fontsize=10, color='#58C1B2')
#plt.annotate(WorkOneTitle, (.02,.508), weight='bold', fontsize=10)
#plt.annotate(WorkOneTime, (.02,.493), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkOneDesc, (.04,.445), weight='regular', fontsize=9)
#plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
#plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
#plt.annotate(WorkThreeTitle, (.02,.295), weight='bold', fontsize=10)
#plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
#plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')


#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg


#ax = fig.add_subplot(111)
#ax.plot(range(0,100), sin(range(0,100)))


#fig.savefig('test.eps', bbox_inches='tight',pad_inches=0)
#pt.close()
#arr_code = mpimg.imread('C:/Users/supri/OneDrive/Pictures/supriyakosuri.jpeg')
#imagebox = OffsetImage(arr_code)
#ab = AnnotationBbox(imagebox,(0.84, 0.12))
#ax.add_artist(ab)
#Function to generate the QR code and save it

# %%
def generateCode():
  #Creating a QRCode object of the size specified by the user
  qr = qrcode.QRCode(version = size.get(),
            box_size = 10,
            border = 5)
  qr.add_data(text.get()) #Adding the data to be encoded to the QRCode object
  qr.make(fit = True) #Making the entire QR Code space utilized
  img = qr.make_image() #Generating the QR Code
  fileDirec=loc.get()+'\\'+name.get() #Getting the directory where the file has to be save
  img.save(f'{fileDirec}.png') #Saving the QR Code
  #Showing the pop up message on saving the file
  messagebox.showinfo("DataFlair QR Code Generator","QR Code is saved successfully!")

# %% [markdown]
# # plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # width_in = 5
# fig = plt.figure(1, figsize=(width_in, 2))
# ax = fig.add_subplot(111)
# ax.plot(range(0,100), sin(range(0,100)))
#
# fig.tight_layout()
# fig.savefig('test.eps', bbox_inches='tight', pad_inches=0)
# plt.close()

# %%
pip install qrcode
# Out:
# ...
#   Created wheel for qrcode: filename=qrcode-7.3.1-py3-none-any.whl size=40401 sha256=792b83c925d19f90e4cffe3e449fe2de34b36bf3cb5ba003e4c45eab62a023ec
#   Stored in directory: c:\users\supri\appdata\local\pip\cache\wheels\93\54\16\55cec87f8d902ed84b94ab8fdb7e89ae1158c06e130bc83b03
# Successfully built qrcode
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pypng
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import QRCode from pyqrcode
import pyqrcode
import png
from pyqrcode import QRCode


# String which represents the QR code
s = "RESUME BUILDER.ipynb"

# Generate QR code
url = pyqrcode.create(s)

# Create and save the svg file naming "myqr.svg"
url.svg("myqr.svg", scale = 8)
  
# Create and save the png file naming "myqr.png"
url.png('myqr.png', scale = 6)

# %%
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # profile

# %%
Name = 'kosuri sai supriya'
#phone number
Contact = 'kondavaram near pithapuram'
# objective
profile_description=" i would like to work in the MNC company with the development of my skills"

# %% [markdown]
# # Education

# %%
# for only header you don't write any thing here!!!
EduHeader = 'EDUCATION'

# %% [markdown]
# # degree

# %%
# degree college name
EduOneTitle = 'Example University, Bachelor of Business Administration'
# year
EduOneTime = '2000-2004'
#degree_GPA
EduOneDesc = '- GPA : 10'

# %% [markdown]
# # inter

# %%
# inter college name
EduTwoTitle = 'Example University, Master of Arts'
# year
EduTwoTime = '2013-2017'
#GPA
EduOneDesc_2 = '- GPA: 9'

# %% [markdown]
# # project

# %%
# header dont consider this!!!
ProjectsHeader = 'PROJECTS '

# %%
#project 1
ProjectOneTitle = 'Increasing Kaggle Revenue'
ProjectOneDesc = '- Published by Towards Data Science\n- Analyzed user survey to recommend most profitable future revenue source\n- Cleaned/visualized data using pandas/matplotlib libraries in Python'
#project 2
ProjectTwoTitle = 'NYC School Data Cleaning & Analysis'
ProjectTwoDesc = '- Cleaned and combined several tables using pandas library in Python\n- Used PDE and visualization to determine correlations for future study'
#project 3
ProjectThreeTitle = 'Pandas Cleaning and Visualization'
ProjectThreeDesc = '- Cleaned data for analysis using pandas library in Python\n- Used pandas and matplotlib to explore which cars hold the most value over time'

# %% [markdown]
# # certifucates

# %%
#dont over write !!!
certificateHeader ='CERTIFICATES'

# %%
certificate_1="-participated in elocution conducted at the JNTU district level"
certificate_2="-completed dhakshin prachar sabha examination "
certificate_3="-won gold medal in NMO"

# %%
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# %%
# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))
# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')
# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
#plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(profile_description,(.0,.890))
plt.annotate(profile_description,(.0,.870))
plt.annotate(profile_description,(.0,.850))
################## education ###########
plt.annotate(EduHeader, (.02,.800), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle,(.02,.780), weight='bold', fontsize=10)
plt.annotate(EduOneTime,(.03,.760), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.02,.7400), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.7200), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.03,.700), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc_2, (.03,.6800), weight='regular', fontsize=9, alpha=.6)
##################### projects ###############3
plt.annotate(ProjectsHeader, (.02,.6500), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.6200), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.03,.5600), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.5400), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.5000), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.4800), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.4400), weight='regular', fontsize=9)
################ certificates ###########
plt.annotate(certificateHeader, (.02,.4000), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(certificate_1,(.1,.3800), weight='regular', fontsize=10)
plt.annotate(certificate_1,(.1,.3600), weight='regular', fontsize=10)
plt.annotate(certificate_1,(.1,.3400), weight='regular', fontsize=10)

 ###################### certifications ##############
certificationsHeader="CertificationsHeader"
certification_1=" participated in SQL compitation"
plt.annotate(certificationsHeader, (.02,.3000), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(certification_1,(.1,.2800), weight='regular', fontsize=10)
plt.annotate(certification_2,(.1,.2500), weight='regular', fontsize=10)
 ################### skills ##########
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
# Out:
# Text(0.7, 0.345, 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis')

# %%
fig.savefig('resumeexample.pdf', dpi=200, bbox_inches='tight',pad_inches=0)
